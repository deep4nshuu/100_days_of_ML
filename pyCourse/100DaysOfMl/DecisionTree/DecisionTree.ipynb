# %% [markdown]
# # Decision Tree
# It is a Low Bias and High Variance algo
# <img src='img1.png'></img>
# <img src='img2.png'></img>
# <img src='img3.png'></img>
# <img src='img4.png'></img>
#
# - Programatically, DT are nothing but a giant structure of nested if else condition
# - Mathematically, DT use hyperplanes which run parallel to any one of the axes to cut your coordinate system into hyper cuboids
#
# > Pseudo code
#
# <img src='img5.png'></img>
#
# > Advantages
# - Intuitive and easy to understand
# - Minimal data preparation is required
# - The cost of using the tree for inference is logarithmic in number of data pts used to train the tree
#
# > Disadvantages
# - Overfitting can occur
# - Prone to errors for imbalanced datasets
#
# > CART
# - CART : Classifictn and Regression Trees
# - The logic of decision trees cna also be applied to regression problems, hence the name is CART

# %% [markdown]
# # Entropy
#
# - Entropy is nothing but the measure of disorder or the measure of purity/impurity
# - More knowledge -> less entropy
#
# <img src='img6.png'></img>
#
# > Observatn
# - More the uncertaininty -> more is entropy
# - For a 2 class problem the min entropy is 0 and the max is 1
# - For more than 2 classes, the min entropy is 0 but the max can be more than 1
# - Both log2 or loge can be used to calculate entropy
#
# > Entropy vs Probability
#
# <img src='img7.png'></img>
#
# > Entropy for continuous variables
# - While ploting kdeplot of entropy, whichever is less peaked or have less peakedness have More entropy

# %% [markdown]
# # Information Gain
# Information Gain is a metric used to train Decision Tree. Specially, this metrci measures the quality of a split.
# The info gain is based on the decrease in entropy avter a dataset is split on an attribute that returns the highest info gain
# - Info Gain = E(Parent) - {Weighted Average} * E{Children}
#
# > Steps to calculate Info Gain
# 1. Find Entropy of Parent, E(P)
# 2. Calculate the Entropy of Children, E(C)
# 3. Calculate Weighted Entropy of Children, W.E(C)
# 4. Calculate the Info Gain
# 5. Calculate Info Gai for all the cols
# - Whichever cols has highest Info gain(Max dec in Entropy) -> Algo will select that col to split data
# 6. Find Info Gain recursively
#
#
# > Gini Impurity
# - It is a measure of impure/pure nodes after spliting dataset
# - Means measures purity of split
# - Formula : G = 1 - (P(y)^2 + P(n)^2)
# - Info Gain = G(P) - WT * G(C)
# <img src='img8.png'></img>

# %% [markdown]
# > Overfitting
# - Training - Perform well
# - Test - Perform badly
# - Max_depth = None -> means no stopping or freeflow -> overfit
# - If max depth is more -> But leaf node is noisy/outlier/errorneous -> no benefit of spliting -> wrong predictn -> Overfitting
#
# > Underfitting
# - Training - Perform bad
# - Max_depth = 1 or less -> means underfitting -> no chance of splitting more -> not able to predict or generalise it

# %% [markdown]
# # HyperParameters
# - Criteria : Gini & Entropy
# - Splitter : Means how data is split -> Best(chance of overfitting) and Random(reduce overfitting)
# - Max_depth(level of tree) : none or high val -> freeflow -> high chance of overfit, if equal to 1 -> chance of underfit inc
# - Min_sample_split : means spliting occur only when specific defined min sample rows present in dataset (High val of min_sample -> underfit and low val -> overfit)
# - Min sample leaf : means leaf node should have this min no of rows
# - Max features : define no of cols used to split
# - Max leaf nodes : define max no of leaf nodes
# - Min_Impurity_dec : define min gini impurity to do split

# %% [markdown]
# > Regression Tree
# - Regression tree is a Decision tree for Regression problems

# %% [markdown]
# >Feature_importance attribute
# - Present inside DT, it provide the percentage of importance of cols by evaluating the value of cols used for making DT
# - Used in Feature Selectn

# %% [markdown]
# # Decision Tree Lib: dtreeviz
#
# - Used to visualize the DT which you have trained

# %%
import graphviz.backend as be
import dtreeviz

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG

# %%
clas = DecisionTreeClassifier(max_depth=2)
iris = load_iris()

x_tr = iris.data
y_tr = iris.target
clas.fit(x_tr, y_tr)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]')]

# %% [markdown]
# 1. Classificatn

# %%
viz = dtreeviz(clas,
               x_tr,
               y_tr,
               features_name=iris.feature_names,
               class_name=["setosa","versicolor","virginica"])

viz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 viz = dtreeviz(clas,
#       2                x_tr,
#       3                y_tr,
#       4                features_name=iris.feature_names,
#       5                class_name=["setosa","versicolor","virginica"])
#       7 viz
#
# TypeError: 'module' object is not callable. Did you mean: 'dtreeviz.dtreeviz(...)'?
