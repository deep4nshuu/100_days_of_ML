# %% [markdown]
# <h2 style='color: red'>How to understand Data</h2>
#
# - Basic things
# - EDA(univariate,bivariate)
# - EDA(multivariate)
# - Pandas Profiling

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\python\pyCourse\csvFiles\titanic\train.csv')

# %% [markdown]
# <h3 style='color: brown'>1. How big is data</h3>

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# <h3 style='color: brown'>2. How data look like </h3>

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 32            33         1       3     Glynn, Miss. Mary Agatha  female   NaN
# 124          125         0       1  White, Mr. Percival Wayland    male  54.0
# 213          214         0       2  Givard, Mr. Hans Kristensen    male  30.0
# 113          114         0       3      Jussila, Miss. Katriina  female  20.0
# 371          372         0       3    Wiklund, Mr. Jakob Alfred    male  18.0
#
#      SibSp  Parch   Ticket     Fare Cabin Embarked
# 32       0      0   335677   7.7500   NaN        Q
# 124      0      1    35281  77.2875   D26        S
# 213      0      0   250646  13.0000   NaN        S
# 113      1      0     4136   9.8250   NaN        S
# 371      1      0  3101267   6.4958   NaN        S

# %% [markdown]
# <h3 style='color: brown'>3. What is the datatypes of cols</h3>
#
# - Means checking data types by finding unusual datatype assigned to any val which leads to take more space

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <h3 style='color: brown'>4. Are there any missing values</h3>

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# <h3 style='color: brown'>5. How does the data look mathematically</h3>

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <h3 style='color: brown'>6. Are there duplicates values</h3>

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <h3 style='color: brown'>7. How is the corr b/w cols </h3>
#
# - Helps in finding the un-usual cols and reducing them

# %%
# df.corr()['Survived']
